# %%
# %pip install roboflow
# %pip install ultralytics
# Out:
# Requirement already satisfied: roboflow in d:\anaconda\lib\site-packages (1.1.66)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from roboflow) (2021.10.8)
# Requirement already satisfied: urllib3>=1.26.6 in d:\anaconda\lib\site-packages (from roboflow) (1.26.9)
# Requirement already satisfied: pillow-heif>=0.18.0 in d:\anaconda\lib\site-packages (from roboflow) (0.22.0)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from roboflow) (3.5.1)
# Requirement already satisfied: cycler in d:\anaconda\lib\site-packages (from roboflow) (0.11.0)
# Requirement already satisfied: python-dotenv in d:\anaconda\lib\site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: tqdm>=4.41.0 in d:\anaconda\lib\site-packages (from roboflow) (4.64.0)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: PyYAML>=5.3.1 in d:\anaconda\lib\site-packages (from roboflow) (6.0)
# Requirement already satisfied: requests-toolbelt in d:\anaconda\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in d:\anaconda\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: python-dateutil in d:\anaconda\lib\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from roboflow) (2.27.1)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in d:\anaconda\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: numpy>=1.18.5 in d:\anaconda\lib\site-packages (from roboflow) (2.0.2)
# Requirement already satisfied: idna==3.7 in d:\anaconda\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\lib\site-packages (from roboflow) (1.3.2)
# Requirement already satisfied: Pillow>=7.1.2 in d:\anaconda\lib\site-packages (from roboflow) (11.2.1)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib->roboflow) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib->roboflow) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib->roboflow) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda\lib\site-packages (from requests->roboflow) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ultralytics in d:\anaconda\lib\site-packages (8.3.159)
# Requirement already satisfied: requests>=2.23.0 in d:\anaconda\lib\site-packages (from ultralytics) (2.27.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in d:\anaconda\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: psutil in d:\anaconda\lib\site-packages (from ultralytics) (5.8.0)
# Requirement already satisfied: py-cpuinfo in d:\anaconda\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: tqdm>=4.64.0 in d:\anaconda\lib\site-packages (from ultralytics) (4.64.0)
# Requirement already satisfied: opencv-python>=4.6.0 in d:\anaconda\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\anaconda\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: numpy>=1.23.0 in d:\anaconda\lib\site-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: torch!=2.4.0,>=1.8.0 in d:\anaconda\lib\site-packages (from ultralytics) (2.0.1+cu117)
# Requirement already satisfied: scipy>=1.4.1 in d:\anaconda\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torchvision>=0.9.0 in d:\anaconda\lib\site-packages (from ultralytics) (0.15.2+cu117)
# Requirement already satisfied: pillow>=7.1.2 in d:\anaconda\lib\site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pandas>=1.1.4 in d:\anaconda\lib\site-packages (from ultralytics) (1.4.2)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\anaconda\lib\site-packages (from ultralytics) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=1.1.4->ultralytics) (2021.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.23.0->ultralytics) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (2.11.3)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: networkx in d:\anaconda\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (2.7.1)
# Requirement already satisfied: sympy in d:\anaconda\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\lib\site-packages (from jinja2->torch!=2.4.0,>=1.8.0->ultralytics) (2.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anaconda\lib\site-packages (from sympy->torch!=2.4.0,>=1.8.0->ultralytics) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Get Dataset

# %%
# %pip install roboflow

from roboflow import Roboflow # type: ignore
rf = Roboflow(api_key="3205MH29k2z3u5Ejc3HU")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# Requirement already satisfied: roboflow in d:\anaconda\lib\site-packages (1.1.66)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\lib\site-packages (from roboflow) (1.3.2)
# Requirement already satisfied: numpy>=1.18.5 in d:\anaconda\lib\site-packages (from roboflow) (2.0.2)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in d:\anaconda\lib\site-packages (from roboflow) (1.26.9)
# Requirement already satisfied: filetype in d:\anaconda\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from roboflow) (2021.10.8)
# Requirement already satisfied: python-dateutil in d:\anaconda\lib\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: tqdm>=4.41.0 in d:\anaconda\lib\site-packages (from roboflow) (4.64.0)
# Requirement already satisfied: requests-toolbelt in d:\anaconda\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: cycler in d:\anaconda\lib\site-packages (from roboflow) (0.11.0)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in d:\anaconda\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in d:\anaconda\lib\site-packages (from roboflow) (11.2.1)
# Requirement already satisfied: python-dotenv in d:\anaconda\lib\site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: PyYAML>=5.3.1 in d:\anaconda\lib\site-packages (from roboflow) (6.0)
# Requirement already satisfied: pillow-heif>=0.18.0 in d:\anaconda\lib\site-packages (from roboflow) (0.22.0)
# Requirement already satisfied: idna==3.7 in d:\anaconda\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from roboflow) (3.5.1)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from roboflow) (2.27.1)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib->roboflow) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib->roboflow) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib->roboflow) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda\lib\site-packages (from requests->roboflow) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [5], in <cell line: 4>()
#       1 get_ipython().run_line_magic('pip', 'install roboflow')
#       3 from roboflow import Roboflow # type: ignore
# ----> 4 rf = Roboflow(api_key="3205MH29k2z3u5Ejc3HU")
#       5 project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
#       6 version = project.version(6)
#
# File d:\anaconda\lib\site-packages\roboflow\__init__.py:212, in Roboflow.__init__(self, api_key, model_format, notebook)
#     210 self.notebook = notebook
#     211 self.onboarding = False
# --> 212 self.auth()
#
# File d:\anaconda\lib\site-packages\roboflow\__init__.py:215, in Roboflow.auth(self)
#     214 def auth(self):
# --> 215     r = check_key(self.api_key, self.model_format, self.notebook)
#     217     if r == "onboarding":
#     218         self.onboarding = True
#
# File d:\anaconda\lib\site-packages\roboflow\__init__.py:36, in check_key(api_key, model, notebook, num_retries)
#      33 response = requests.post(API_URL + "/?api_key=" + api_key)
#      35 if response.status_code == 401:
# ---> 36     raise RuntimeError(response.text)
#      38 if response.status_code != 200:
#      39     # retry 5 times
#      40     if num_retries < 5:
#
# RuntimeError: {
#     "error": {
#         "message": "This API key does not exist (or has been revoked).",
#         "status": 401,
#         "type": "OAuthException",
#         "hint": "You may retrieve your API key via the Roboflow Dashboard. Go to Account > Roboflow Keys to retrieve yours.",
#         "key": "3205MH29k2z3u5Ejc3HU"
#     }
# }

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train",
"tennis-ball-detection-6/tennis-ball-detection-6/train",
)
shutil.move("tennis-ball-detection-6/test",
"tennis-ball-detection-6/tennis-ball-detection-6/test",
)
shutil.move("tennis-ball-detection-6/valid",
"tennis-ball-detection-6/tennis-ball-detection-6/valid",
)
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
